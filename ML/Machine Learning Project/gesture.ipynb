# %%
# %pip install open3d
# Out:
# Collecting open3d
#   Obtaining dependency information for open3d from https://files.pythonhosted.org/packages/91/79/7609d49bb8c86d5dcd9684f72449b512d8787708f975fd003acb78c63786/open3d-0.18.0-cp311-cp311-macosx_13_0_arm64.whl.metadata
#   Downloading open3d-0.18.0-cp311-cp311-macosx_13_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.18.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (1.24.3)
# Collecting dash>=2.6.0 (from open3d)
#   Obtaining dependency information for dash>=2.6.0 from https://files.pythonhosted.org/packages/7b/62/438626ab498869249e99376684ba6d88931e7c2dd86d03a92d9d7a9b4c54/dash-2.14.2-py3-none-any.whl.metadata
#   Downloading dash-2.14.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: werkzeug>=2.2.3 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (2.2.3)
# Requirement already satisfied: nbformat>=5.7.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (5.9.2)
# Collecting configargparse (from open3d)
#   Obtaining dependency information for configargparse from https://files.pythonhosted.org/packages/6f/b3/b4ac838711fd74a2b4e6f746703cf9dd2cf5462d17dac07e349234e21b97/ConfigArgParse-1.7-py3-none-any.whl.metadata
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Collecting addict (from open3d)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: pillow>=9.3.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (9.4.0)
# Requirement already satisfied: matplotlib>=3 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (3.7.2)
# Requirement already satisfied: pandas>=1.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (2.0.3)
# Requirement already satisfied: pyyaml>=5.4.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (6.0)
# Requirement already satisfied: scikit-learn>=0.21 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (1.3.0)
# Requirement already satisfied: tqdm in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from open3d) (4.65.0)
# Collecting pyquaternion (from open3d)
#   Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from dash>=2.6.0->open3d) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from dash>=2.6.0->open3d) (5.9.0)
# Collecting dash-html-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from dash>=2.6.0->open3d) (4.7.1)
# Requirement already satisfied: requests in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from dash>=2.6.0->open3d) (2.31.0)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash>=2.6.0->open3d)
#   Obtaining dependency information for ansi2html from https://files.pythonhosted.org/packages/42/d7/1bc3433a2406b891182c25a7926abe3eb19af5870d540375ebf7795885b3/ansi2html-1.9.1-py3-none-any.whl.metadata
#   Downloading ansi2html-1.9.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: nest-asyncio in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from dash>=2.6.0->open3d) (1.5.6)
# Requirement already satisfied: setuptools in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from dash>=2.6.0->open3d) (68.0.0)
# Requirement already satisfied: importlib-metadata in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from dash>=2.6.0->open3d) (6.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3->open3d) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3->open3d) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3->open3d) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3->open3d) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3->open3d) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3->open3d) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3->open3d) (2.8.2)
# Requirement already satisfied: fastjsonschema in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from nbformat>=5.7.0->open3d) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from nbformat>=5.7.0->open3d) (4.17.3)
# Requirement already satisfied: jupyter-core in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from nbformat>=5.7.0->open3d) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from nbformat>=5.7.0->open3d) (5.7.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->open3d) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->open3d) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.21->open3d) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.21->open3d) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.21->open3d) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from werkzeug>=2.2.3->open3d) (2.1.1)
# Requirement already satisfied: Jinja2>=3.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (2.0.1)
# Requirement already satisfied: click>=8.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (8.0.4)
# Requirement already satisfied: attrs>=17.4.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.2.2)
# Requirement already satisfied: six>=1.5 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.11.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from jupyter-core->nbformat>=5.7.0->open3d) (3.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.6.0->open3d) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.6.0->open3d) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.6.0->open3d) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.6.0->open3d) (2023.7.22)
# Downloading open3d-0.18.0-cp311-cp311-macosx_13_0_arm64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 8.5 MB/s eta 0:00:0000:01m0:01m
# Downloading dash-2.14.2-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 34.5 MB/s eta 0:00:00 0:00:01
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading ansi2html-1.9.1-py3-none-any.whl (17 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, addict, retrying, pyquaternion, configargparse, ansi2html, dash, open3d
# Successfully installed addict-2.4.0 ansi2html-1.9.1 configargparse-1.7 dash-2.14.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 open3d-0.18.0 pyquaternion-0.9.9 retrying-1.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install mediapipe
# Out:
# Collecting mediapipe
#   Obtaining dependency information for mediapipe from https://files.pythonhosted.org/packages/a3/3a/f309c6bdebe596cc8c960542e167331cb01ef130ec38f3da46a499718889/mediapipe-0.10.9-cp311-cp311-macosx_11_0_universal2.whl.metadata
#   Downloading mediapipe-0.10.9-cp311-cp311-macosx_11_0_universal2.whl.metadata (9.6 kB)
# Requirement already satisfied: absl-py in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from mediapipe) (3.7.2)
# Requirement already satisfied: numpy in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from mediapipe) (1.24.3)
# Collecting opencv-contrib-python (from mediapipe)
#   Obtaining dependency information for opencv-contrib-python from https://files.pythonhosted.org/packages/4c/c3/ccff2e1bfe2bb47a7eaebc4280e93bd2f97ebbe5b3573d48bcfcc0c32387/opencv_contrib_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting protobuf<4,>=3.11 (from mediapipe)
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.3 MB/s eta 0:00:00
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: CFFI>=1.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /Users/shinjongsoo/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.9-cp311-cp311-macosx_11_0_universal2.whl (47.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 MB 34.8 MB/s eta 0:00:0000:0100:01
# Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (44.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 44.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: protobuf, opencv-contrib-python, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.4
#     Uninstalling protobuf-4.23.4:
#       Successfully uninstalled protobuf-4.23.4
# Successfully installed mediapipe-0.10.9 opencv-contrib-python-4.9.0.80 protobuf-3.20.3 sounddevice-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from utils_display import DisplayHand
from utils_mediapipe import MediaPipeHand
from utils_joint_angle import GestureRecognition
import numpy as np
import time
import subprocess
import argparse

# ArgumentParser 생성
parser = argparse.ArgumentParser()
parser.add_argument('-m', '--mode', default='eval', help='train / eval')
args, unknown_args = parser.parse_known_args()

# mode 변수 설정
mode = args.mode

# mediapipe hand 클래스 로드
pipe = MediaPipeHand(static_image_mode=False, max_num_hands=4)

# 디스플레이 클래스 로드
disp = DisplayHand(max_num_hands=1)

# 비디오 캡처 시작
cap = cv2.VideoCapture(1)

# 제스처 인식 클래스 로드
gest = GestureRecognition(mode)

# 'home' 제스처가 인식된 시간을 저장하는 변수
home_start_time = None

while cap.isOpened():
    ret, img = cap.read()
    if not ret:
        break

    # 3인칭 뷰를 위해 이미지 뒤집기
    img = cv2.flip(img, 1)

    # 이미지를 참조로 전달할 수 없게 설정
    img.flags.writeable = False

    # 피드포워드를 통해 키포인트 추출
    param = pipe.forward(img)

    if (param[0]['class'] is not None) and (mode == 'eval'):
        param[0]['gesture'] = gest.eval(param[0]['angle'])
        
        # 'home' 제스처가 인식되면 음성 출력 및 시간 기록
        if param[0]['gesture'] == 'home':
            if home_start_time is None:
                home_start_time = time.time()
            else:
                elapsed_time = time.time() - home_start_time
                if elapsed_time >= 3:  # 3초 이상 동안 'home' 제스처가 인식되면
                    subprocess.run(["say", "안내를 시작합니다"])  # macOS에서는 say 명령어를 사용하여 TTS 실행
                    home_start_time = None  # 초기화
        else:
            home_start_time = None  # 'home' 제스처가 아닌 경우 초기화

    # 이미지를 참조로 전달할 수 있게 설정
    img.flags.writeable = True

    # 키포인트를 2D로 그려서 표시
    disp.draw2d(img, param)

    # 창에 이미지 표시
    cv2.imshow('img 2D', img)

    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1704950112.105832       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 2024-01-11 14:15:12.298 python[8716:266463] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
